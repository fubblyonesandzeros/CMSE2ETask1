# %%
import os
os.chdir("/kaggle/input/d/danielikechukwu/ml4scitest1src/ML4SciTest1/src")

# %%
# !ls /kaggle/working
# Out:
# __notebook__.ipynb

# %%
# !python train_resnet_classification.py --dir "/kaggle/working"
# Out:
# ...
# 100%|███████████████████████████████████████| 1557/1557 [00:33<00:00, 46.00it/s]
